# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Context

# %%
train=pd.read_csv('train.csv',index_col='PassengerId')
train
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Name      100000 non-null  object
#  3   Sex       100000 non-null  object
#  4   Age       96708 non-null   float64
#  5   SibSp     100000 non-null  int64
#  6   Parch     100000 non-null  int64
#  7   Ticket    95377 non-null   object
#  8   Fare      99866 non-null   float64
#  9   Cabin     32134 non-null   object
#  10  Embarked  99750 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 9.2+ MB

# %%
train['Survived'].value_counts()
# Out:
# 0    57226
# 1    42774
# Name: Survived, dtype: int64

# %%
train['Pclass'].value_counts()
# Out:
# 3    41006
# 1    30315
# 2    28679
# Name: Pclass, dtype: int64

# %%
train['Name'].value_counts()
# Out:
# Johnson, John           31
# Smith, James            24
# Smith, John             24
# Johnson, William        22
# Smith, Michael          20
#                         ..
# Christensen, Cinthia     1
# Roblez, Mildred          1
# Stainback, Maria         1
# Ford, Joyce              1
# Matthews, Donna          1
# Name: Name, Length: 92144, dtype: int64

# %%
train['SibSp'].value_counts()
# Out:
# 0    73308
# 1    19758
# 2     3703
# 3     1635
# 4     1168
# 8      296
# 5      132
# Name: SibSp, dtype: int64

# %%
train['Parch'].value_counts()
# Out:
# 0    73540
# 1    12996
# 2    11236
# 3      983
# 4      446
# 5      331
# 9      264
# 6      204
# Name: Parch, dtype: int64

# %%
train['Ticket'].value_counts()
# Out:
# A/5             602
# C.A.            177
# SC/PARIS        145
# SOTON/O.Q.       80
# SC               57
#                ...
# A. 25569          1
# 342863            1
# 433196            1
# 7664              1
# SC/AH 464172      1
# Name: Ticket, Length: 75331, dtype: int64

# %%
train['Cabin'].value_counts()
# Out:
# C19828    6
# C9485     5
# B11110    5
# C11139    5
# C11283    5
#          ..
# D4065     1
# C17580    1
# A2345     1
# C20725    1
# C2429     1
# Name: Cabin, Length: 26992, dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# S    72139
# C    22187
# Q     5424
# Name: Embarked, dtype: int64

# %% [markdown]
# # Data quality assessment

# %% [markdown]
# Check dublicates

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare', 'Cabin', 'Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Parch','Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Ticket','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Fare','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Cabin','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare','Embarked']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch','Ticket','Fare','Cabin']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Name', 'Sex', 'Age']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Name', 'Sex', 'Age','Ticket']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Name', 'Sex', 'Age','Pclass']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %%
key = ['Name','Ticket']
train.drop_duplicates(subset=key)
# Out:
#              Survived  Pclass                Name     Sex    Age  SibSp  \
# PassengerId
# 0                   1       1    Oconnor, Frankie    male    NaN      2
# 1                   0       3         Bryan, Drew    male    NaN      0
# 2                   0       3      Owens, Kenneth    male   0.33      1
# 3                   0       3       Kramer, James    male  19.00      0
# 4                   1       3       Bond, Michael    male  25.00      0
# ...               ...     ...                 ...     ...    ...    ...
# 99995               1       2         Bell, Adele  female  62.00      0
# 99996               0       2       Brown, Herman    male  66.00      0
# 99997               0       3  Childress, Charles    male  37.00      0
# 99998               0       3    Caughlin, Thomas    male  51.00      0
# 99999               0       3       Enciso, Tyler    male  55.00      0
#
#              Parch     Ticket   Fare   Cabin Embarked
# PassengerId
# ...

# %% [markdown]
# Dublicates were checked in dataset. There aren't full dublicates involved all columns. At least one feature was different. For example, when we have dublicates in columns 'Name', 'Sex', 'Age', we have difference between contents of 'Ticket'. Dublicates in columns can be real.

# %%
useless_column=['Ticket','Name']
train=train.drop(columns=useless_column)
train
# Out:
#              Survived  Pclass     Sex    Age  SibSp  Parch   Fare   Cabin  \
# PassengerId
# 0                   1       1    male    NaN      2      0  27.14  C12239
# 1                   0       3    male    NaN      0      0  13.35     NaN
# 2                   0       3    male   0.33      1      2  71.29     NaN
# 3                   0       3    male  19.00      0      0  13.04     NaN
# 4                   1       3    male  25.00      0      0   7.76     NaN
# ...               ...     ...     ...    ...    ...    ...    ...     ...
# 99995               1       2  female  62.00      0      0  14.86  D17243
# 99996               0       2    male  66.00      0      0  11.15     NaN
# 99997               0       3    male  37.00      0      0   9.95     NaN
# 99998               0       3    male  51.00      0      1  30.92     NaN
# 99999               0       3    male  55.00      0      0  13.96     NaN
#
#             Embarked
# PassengerId
# 0                  S
# ...

# %% [markdown]
# Fill in the gaps

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Sex       100000 non-null  object
#  3   Age       96708 non-null   float64
#  4   SibSp     100000 non-null  int64
#  5   Parch     100000 non-null  int64
#  6   Fare      99866 non-null   float64
#  7   Cabin     32134 non-null   object
#  8   Embarked  99750 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
train['Embarked'].fillna(train['Embarked'].mode()[0],inplace=True)
train['Embarked'].value_counts()
# Out:
# S    72389
# C    22187
# Q     5424
# Name: Embarked, dtype: int64

# %%
train['Deck']=train['Cabin'].str.slice(0,1)
train['Deck'].fillna('X',inplace=True)
train=train.drop(columns=['Cabin'])
train
# Out:
#              Survived  Pclass     Sex    Age  SibSp  Parch   Fare Embarked  \
# PassengerId
# 0                   1       1    male    NaN      2      0  27.14        S
# 1                   0       3    male    NaN      0      0  13.35        S
# 2                   0       3    male   0.33      1      2  71.29        S
# 3                   0       3    male  19.00      0      0  13.04        S
# 4                   1       3    male  25.00      0      0   7.76        S
# ...               ...     ...     ...    ...    ...    ...    ...      ...
# 99995               1       2  female  62.00      0      0  14.86        C
# 99996               0       2    male  66.00      0      0  11.15        S
# 99997               0       3    male  37.00      0      0   9.95        S
# 99998               0       3    male  51.00      0      1  30.92        S
# 99999               0       3    male  55.00      0      0  13.96        S
#
#             Deck
# PassengerId
# 0              C
# ...

# %%
train['Fare'] = train.groupby(['Pclass'])['Fare'].transform(lambda group: group.fillna(group.mean()))
train['Age'] = train.groupby(['Pclass'])['Age'].transform(lambda group: group.fillna(group.mean()))
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Sex       100000 non-null  object
#  3   Age       100000 non-null  float64
#  4   SibSp     100000 non-null  int64
#  5   Parch     100000 non-null  int64
#  6   Fare      100000 non-null  float64
#  7   Embarked  100000 non-null  object
#  8   Deck      100000 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
train
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch   Fare  \
# PassengerId
# 0                   1       1    male  44.774464      2      0  27.14
# 1                   0       3    male  33.407362      0      0  13.35
# 2                   0       3    male   0.330000      1      2  71.29
# 3                   0       3    male  19.000000      0      0  13.04
# 4                   1       3    male  25.000000      0      0   7.76
# ...               ...     ...     ...        ...    ...    ...    ...
# 99995               1       2  female  62.000000      0      0  14.86
# 99996               0       2    male  66.000000      0      0  11.15
# 99997               0       3    male  37.000000      0      0   9.95
# 99998               0       3    male  51.000000      0      1  30.92
# 99999               0       3    male  55.000000      0      0  13.96
#
#             Embarked Deck
# PassengerId
# 0                  S    C
# 1                  S    X
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Sex       100000 non-null  object
#  3   Age       100000 non-null  float64
#  4   SibSp     100000 non-null  int64
#  5   Parch     100000 non-null  int64
#  6   Fare      100000 non-null  float64
#  7   Embarked  100000 non-null  object
#  8   Deck      100000 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
train['Deck'].value_counts()
# Out:
# X    67866
# C    11825
# B     7439
# A     6307
# D     3637
# E     1749
# F      663
# G      482
# T       32
# Name: Deck, dtype: int64

# %% [markdown]
# The gaps in Embarked column were filled by "mode". The gaps in 'Fare' and 'Age' columns were filled by "mean" according to every subgroup in 'Pclass' column. Columns 'Name', 'Ticket','Cabin' were deleted. There is new column 'Deck' that includes the first letter from 'Cabin' and 'X' instead of gaps.

# %% [markdown]
# # Data exploration

# %%
sns.catplot('Sex', data=train, hue='Survived', kind='count')
# Out:
# C:\Users\burlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Males died more often than women and more than survived

# %%
sns.catplot('Sex', data=train, kind='count')
# Out:
# C:\Users\burlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Males were more than females

# %%
sns.catplot('Pclass', data=train, kind='count')
# Out:
# C:\Users\burlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Poor people were more

# %%
sns.catplot('Pclass', data=train, hue='Sex', kind='count')
# Out:
# C:\Users\burlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Poor males were more

# %%
sns.catplot(x='Sex', y='Survived', col='Pclass', data=train, kind='bar')

# %% [markdown]
# Poor males that not survived were more

# %%
sns.catplot(x='SibSp', data=train, hue='Survived', kind='count')

# %% [markdown]
# People without family members died more

# %%
sns.catplot(x='Parch', data=train, hue='Survived', kind='count')

# %% [markdown]
# People without children or parents died more

# %%
train['Family size']=train['Parch']+train['SibSp']
train.head()
# Out:
#              Survived  Pclass   Sex        Age  SibSp  Parch   Fare Embarked  \
# PassengerId
# 0                   1       1  male  44.774464      2      0  27.14        S
# 1                   0       3  male  33.407362      0      0  13.35        S
# 2                   0       3  male   0.330000      1      2  71.29        S
# 3                   0       3  male  19.000000      0      0  13.04        S
# 4                   1       3  male  25.000000      0      0   7.76        S
#
#             Deck  Family size
# PassengerId
# 0              C            2
# 1              X            0
# 2              X            3
# 3              X            0
# 4              X            0

# %%
sns.catplot(x='Family size', data=train, hue='Survived', kind='count')

# %% [markdown]
# People without relatives died more

# %%
sns.catplot(x='Embarked', data=train, hue='Survived', kind='count')

# %% [markdown]
# The most amount of not survived people embarked on S

# %%
sns.catplot(x='Deck', data=train, hue='Survived', kind='count')

# %% [markdown]
# For most not survived people decks were unknown

# %%
train['Age'].plot(edgecolor='black', kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# The most popular age around 20-30 and around 50

# %%
sns.scatterplot(x=train['Age'], y=train['Fare'], hue=train['Sex'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>
# C:\Users\burlo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Summary

# %% [markdown]
# Poor males, people without relatives, people embarked on S and people from unknown cabin surveved less.
